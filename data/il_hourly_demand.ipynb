# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize']=(12,9)
plt.rcParams['font.size'] = '16'

# %%
df = pd.read_csv("./demand_profile.csv")
df
# Out:
#     season hour  demand_frac
# 0   spring   H1     0.008419
# 1   spring   H2     0.008021
# 2   spring   H3     0.007739
# 3   spring   H4     0.007558
# 4   spring   H5     0.007454
# ..     ...  ...          ...
# 91  winter  H20     0.012599
# 92  winter  H21     0.012190
# 93  winter  H22     0.011805
# 94  winter  H23     0.011286
# 95  winter  H24     0.010592
#
# [96 rows x 3 columns]

# %%
seasons = np.unique(df.season)

fig, ax = plt.subplots()
fig.figsize=(12,9)
for season in seasons:
    ax.plot(range(24), df[df.season == season].demand_frac, label=season.capitalize())
plt.xlabel('Hour')
ax.legend()
ax.set_ylabel('Fraction of Total Annual Demand')
plt.show()
fig.savefig("../report/img/seasonal_hourly_demand.png")

# %%
df.demand_frac.sum()
# Out:
# 1.0
